# %%
import os
import pandas as pd

sample_path = None

for dirname, _, filenames in os.walk("/kaggle/input"):
    for filename in filenames:
        if filename == "sample_solution.csv":
            sample_path = os.path.join(dirname, filename)

sample = pd.read_csv(sample_path)

submission = pd.DataFrame({
    "id": sample["id"],
    "spoilerType": "passage"
})

submission.to_csv("/kaggle/working/prediction_task1.csv", index=False)

print(submission.shape)
print(submission.head())
# Out:
# (400, 2)
#    id spoilerType
# 0   0     passage
# 1   1     passage
# 2   2     passage
# 3   3     passage
# 4   4     passage
