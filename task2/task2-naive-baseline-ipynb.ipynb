# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import pandas as pd


test_path = "/kaggle/input/competitions/task-2-clickbait-detection-mse-641-s-26/test.jsonl"

test = pd.read_json(test_path, lines=True)

submission = pd.DataFrame({
    "id": range(len(test)),
    "spoiler": test["targetTitle"]
})

submission.to_csv("prediction_task2.csv", index=False)

print(submission.shape)
print(submission.head())
# Out:
# (400, 2)
#    id                                            spoiler
# 0   0  Male Nurse Breaks Down When His Friend Reveals...
# 1   1  Why you SHOULD be selfish at work: Helping oth...
# 2   2  The One Strange Trick That Will Help You Live ...
# 3   3  Nerd Wins Scrabble Championship With Word You’...
# 4   4  The Bizarre New Way To Eat Eggs That Has Every...
